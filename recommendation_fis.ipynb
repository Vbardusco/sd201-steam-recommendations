# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
from random import randrange, sample
from tqdm import tqdm

df = pd.read_csv('steam-200k.csv')
df.columns = ['id','game','state','hours_played','0']
df['id'].nunique()
df = df.drop('0',axis=1)
df.isnull().values.any()
bought_games = df.loc[df['state']=='purchase']
played_games = df.loc[df['state']=='play']
played_games_orig = played_games.drop(['state'],axis=1)

# %% [markdown]
# We want to see how well we can recommend games using frequent itemset

# %%
grouped = played_games_orig.drop('hours_played', axis=1)
grouped = grouped.groupby('id')['game'].apply(list).reset_index(name='games')
grouped
# Out:
#               id                                              games
# 0           5250  [Cities Skylines, Deus Ex Human Revolution, Po...
# 1          76767  [Counter-Strike, Call of Duty World at War, To...
# 2          86540  [The Elder Scrolls V Skyrim, Audiosurf, XCOM E...
# 3         144736                                   [Counter-Strike]
# 4         181212           [Counter-Strike, Half-Life 2 Lost Coast]
# ...          ...                                                ...
# 11345  309434439                                           [Dota 2]
# 11346  309554670                                [Mitos.is The Game]
# 11347  309626088                     [Age of Empires II HD Edition]
# 11348  309824202                                           [Dota 2]
# 11349  309903146                                           [Dota 2]
#
# [11350 rows x 2 columns]

# %%
te = TransactionEncoder()
te_ary = te.fit(grouped['games']).transform(grouped['games'])
df = pd.DataFrame(te_ary, columns=te.columns_)
df
fis = fpgrowth(df, min_support=0.005, use_colnames=True)
fis = fis.sort_values(by=['support'], ascending=False)
fis
# Out:
#        support                                           itemsets
# 0     0.426520                                           (Dota 2)
# 1     0.204670                                  (Team Fortress 2)
# 6     0.121322                  (Counter-Strike Global Offensive)
# 39    0.094185                                         (Unturned)
# 20    0.070573                                    (Left 4 Dead 2)
# ...        ...                                                ...
# 2128  0.005022  (Team Fortress 2, Sid Meier's Civilization V, ...
# 2933  0.005022  (The Elder Scrolls V Skyrim, Don't Starve Toge...
# 2940  0.005022  (Don't Starve Together Beta, Team Fortress 2, ...
# 2941  0.005022  (Garry's Mod, Team Fortress 2, Don't Starve To...
# 2507  0.005022  (Counter-Strike Global Offensive, The Elder Sc...
#
# [3224 rows x 2 columns]

# %%
ar = association_rules(fis, metric="confidence", min_threshold=0.2)
ar.sort_values(by=['confidence', 'lift'], ascending=False)
# Out:
#                                              antecedents  \
# 4747   (Counter-Strike Condition Zero Deleted Scenes,...
# 1867      (Counter-Strike Condition Zero Deleted Scenes)
# 7369             (Dota 2, Call of Duty Modern Warfare 2)
# 10869  (Counter-Strike Global Offensive, Team Fortres...
# 12547                (Insurgency, Counter-Strike Source)
# ...                                                  ...
# 3693                                          (PAYDAY 2)
# 3641                                          (PAYDAY 2)
# 3728                                          (PAYDAY 2)
# 4792                                  (Dota 2, Unturned)
# 6680                                 (Heroes & Generals)
#
#                                              consequents  antecedent support  \
# 4747                                    (Counter-Strike)            0.006432
# 1867                                    (Counter-Strike)            0.008282
# 7369       (Call of Duty Modern Warfare 2 - Multiplayer)            0.005815
# 10869      (Call of Duty Modern Warfare 2 - Multiplayer)            0.005374
# 12547                  (Counter-Strike Global Offensive)            0.005198
# ...                                                  ...                 ...
# 3693   (Counter-Strike Global Offensive, Team Fortres...            0.034361
# 3641         (Left 4 Dead 2, The Elder Scrolls V Skyrim)            0.034361
# 3728                 (Dota 2, Team Fortress 2, Unturned)            0.034361
# 4792       (Left 4 Dead 2, Garry's Mod, Team Fortress 2)            0.032159
# 6680                               (Robocraft, Unturned)            0.029515
#
#        consequent support   support  confidence       lift  leverage  \
# 4747             0.050044  0.006432    1.000000  19.982394  0.006110
# 1867             0.050044  0.008194    0.989362  19.769816  0.007779
# 7369             0.025639  0.005727    0.984848  38.412475  0.005578
# 10869            0.025639  0.005286    0.983607  38.364036  0.005149
# 12547            0.121322  0.005110    0.983051   8.102852  0.004479
# ...                   ...       ...         ...        ...       ...
# 3693             0.017004  0.006872    0.200000  11.761658  0.006288
# 3641             0.020441  0.006872    0.200000   9.784483  0.006170
# 3728             0.022555  0.006872    0.200000   8.867188  0.006097
# 4792             0.019295  0.006432    0.200000  10.365297  0.005811
# 6680             0.020969  0.005903    0.200000   9.537815  0.005284
#
#        conviction
# 4747          inf
# 1867    89.295859
# 7369    64.307841
# 10869   59.436035
# 12547   51.842026
# ...           ...
# 3693     1.228744
# 3641     1.224449
# 3728     1.221806
# 4792     1.225881
# 6680     1.223789
#
# [13560 rows x 9 columns]

# %%
def recommendation_ar(librairy, fis, ar):
    item_set_tmp = frozenset()

    for i in range(ar.shape[0]):
        if( set(ar.iloc[i][0]).issubset(set(librairy))):
            #print("antecedent : " + str(list(ar.iloc[i][0])) + " | consequent : " + str(list(ar.iloc[i][1])) + " | confidence : " + str(ar.iloc[i][5]))
            item_set_tmp = frozenset.union(item_set_tmp,ar.iloc[i][1])
    #if(one):
    #    for i in range(fis.shape[0]):
    #       if(set(librairy).issubset(set(fis.iloc[i][1]))):
    #            item_set_tmp = frozenset.union(item_set_tmp,fis.iloc[i][1])
    item_set = list(frozenset.difference(item_set_tmp, librairy))
    return item_set

# %%
librairy = ['Cities Skylines']
print(librairy)
print(recommendation_ar(librairy, fis, ar))

for i in range (10):
    librairy = grouped.iloc[i][1]
    print(librairy)
    print(recommendation_ar(librairy, fis, ar))
    print('\n')
# Out:
# ['Cities Skylines']
# ["Sid Meier's Civilization V"]
# ['Cities Skylines', 'Deus Ex Human Revolution', 'Portal 2', 'Alien Swarm', 'Team Fortress 2', 'Dota 2']
# ['Killing Floor', 'Left 4 Dead', 'BioShock Infinite', 'Tomb Raider', 'Chivalry Medieval Warfare', 'Terraria', 'Left 4 Dead 2', "Sid Meier's Civilization V", 'PAYDAY 2', 'PAYDAY The Heist', 'Borderlands 2', 'Counter-Strike Source', 'Half-Life 2', 'Far Cry 3', 'Saints Row The Third', 'Torchlight II', "Garry's Mod", 'The Elder Scrolls V Skyrim', 'The Binding of Isaac', 'Unturned', 'Trine 2', 'Warframe', 'Portal', 'Grand Theft Auto IV', 'Castle Crashers', 'XCOM Enemy Unknown', 'Just Cause 2', 'Magicka', 'Fallout New Vegas', 'Counter-Strike Global Offensive', 'Dead Island', "Mirror's Edge", 'BioShock', 'Dishonored', 'Metro 2033']
#
#
# ['Counter-Strike', 'Call of Duty World at War', 'Total War ATTILA', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Call of Duty Modern Warfare 2', 'Counter-Strike Source', 'Banished', 'Call of Duty Black Ops', 'Call of Duty Modern Warfare 3', 'Portal 2', 'Age of Empires II HD Edition', 'Call of Duty Black Ops - Multiplayer', 'Call of Duty Modern Warfare 3 - Multiplayer', 'Rise of Nations Extended Edition', 'Counter-Strike Global Offensive', 'Thief Deadly Shadows', 'The Stanley Parable', 'Half-Life', 'Alien Swarm', 'Worms Armageddon']
# ['Killing Floor', 'Left 4 Dead', 'Day of Defeat Source', 'BioShock Infinite', 'Terraria', 'Chivalry Medieval Warfare', 'Left 4 Dead 2', "Sid Meier's Civilization V", 'PAYDAY 2', 'Borderlands 2', 'Half-Life 2', 'Team Fortress 2', 'Saints Row The Third', 'Counter-Strike Condition Zero', 'Dota 2', 'DayZ', "Garry's Mod", 'The Elder Scrolls V Skyrim', 'Unturned', 'Warframe', 'Portal', 'Grand Theft Auto IV', 'Arma 2 Operation Arrowhead', 'Just Cause 2', 'Magicka', 'Fallout New Vegas', 'Metro 2033']
#
#
# ['The Elder Scrolls V Skyrim', 'Audiosurf', 'XCOM Enemy Unknown', 'Far Cry 3', 'Left 4 Dead 2', 'Killer is Dead', 'Torchlight II', 'The Walking Dead', 'Max Payne 3', 'Borderlands 2', 'Age of Empires II HD Edition', 'Serious Sam HD The First Encounter', 'Portal', "Tom Clancy's Ghost Recon Advanced Warfighter", 'Alan Wake']
# ['Killing Floor', 'Alien Swarm', 'Portal 2', 'Left 4 Dead', 'BioShock Infinite', 'Tomb Raider', 'Chivalry Medieval Warfare', 'Terraria', 'FTL Faster Than Light', 'Borderlands', "Sid Meier's Civilization V", 'The Witcher 2 Assassins of Kings Enhanced Edition', 'PAYDAY 2', 'Deus Ex Human Revolution', 'Half-Life 2 Episode One', 'PAYDAY The Heist', 'Counter-Strike Source', 'Half-Life 2', 'Team Fortress 2', 'Saints Row The Third', 'Dota 2', "Garry's Mod", 'The Binding of Isaac', 'Unturned', 'Trine 2', 'Warframe', 'Grand Theft Auto IV', 'Just Cause 2', 'Magicka', 'Fallout New Vegas', 'Counter-Strike Global Offensive', 'Dead Island', 'Half-Life 2 Episode Two', 'Dishonored', 'Metro 2033']
#
#
# ['Counter-Strike']
# ['Counter-Strike Global Offensive', 'Dota 2', 'Team Fortress 2', 'Counter-Strike Source', 'Counter-Strike Condition Zero']
#
#
# ['Counter-Strike', 'Half-Life 2 Lost Coast']
# ['Dota 2', 'Left 4 Dead 2', 'Half-Life 2 Episode One', 'Counter-Strike Source', 'Half-Life 2', 'Counter-Strike Global Offensive', 'Half-Life 2 Episode Two', 'Portal', 'Team Fortress 2', 'Half-Life 2 Deathmatch', 'Counter-Strike Condition Zero']
#
#
# ['Counter-Strike Condition Zero', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Counter-Strike', 'Call of Duty Modern Warfare 2', 'Call of Duty Black Ops', 'Half-Life 2 Episode Two', 'Half-Life 2 Episode One', 'Worms Reloaded', 'Call of Duty Black Ops - Multiplayer', 'Counter-Strike Source', 'Half-Life 2', 'Half-Life', 'Team Fortress 2', 'Insurgency Modern Infantry Combat', 'Day of Defeat', 'Half-Life 2 Lost Coast', 'Counter-Strike Condition Zero Deleted Scenes', 'Portal']
# ['Killing Floor', 'Alien Swarm', 'Portal 2', 'Left 4 Dead', 'Day of Defeat Source', 'Terraria', 'Chivalry Medieval Warfare', 'Left 4 Dead 2', "Sid Meier's Civilization V", 'PAYDAY 2', 'Metro 2033', 'Borderlands 2', 'Saints Row The Third', 'Dota 2', 'Torchlight II', "Garry's Mod", 'The Elder Scrolls V Skyrim', 'Call of Duty Modern Warfare 3', 'Unturned', 'Call of Duty Modern Warfare 3 - Multiplayer', 'The Binding of Isaac', 'Grand Theft Auto IV', 'Arma 2 Operation Arrowhead', 'Fallout New Vegas', 'Counter-Strike Global Offensive', 'Half-Life 2 Deathmatch']
#
#
# ['Team Fortress 2', 'Counter-Strike Global Offensive', "Sid Meier's Civilization V", 'The Elder Scrolls V Skyrim', 'Far Cry 3', 'Fallout New Vegas', 'The Witcher 3 Wild Hunt', 'Terraria', 'Fallout 4', 'Borderlands 2', 'DARK SOULS II Scholar of the First Sin', 'Endless Legend', 'METAL GEAR SOLID V THE PHANTOM PAIN', 'Divinity Original Sin', 'DARK SOULS II', 'Pillars of Eternity', 'Starbound', 'Dark Souls Prepare to Die Edition', 'Rocket League', 'ARK Survival Evolved', 'The Witcher 2 Assassins of Kings Enhanced Edition', 'Rust', 'STAR WARS Knights of the Old Republic II The Sith Lords', 'Tropico 4', 'Deus Ex Human Revolution', 'Dishonored', 'XCOM Enemy Unknown', "Shadowrun Dragonfall - Director's Cut", 'Darksiders II', 'BioShock Infinite', 'Legend of Grimrock', 'Dead Island', 'Portal 2', 'Left 4 Dead 2', 'Batman Arkham Origins', 'Mortal Kombat X', 'Hitman Absolution', '7 Days to Die', 'The Walking Dead', 'Torchlight II', 'Wasteland 2', 'Tomb Raider', 'RAGE', 'LEGO MARVEL Super Heroes', 'Shadowrun Returns', 'Chivalry Medieval Warfare', 'Metro Last Light', 'FTL Faster Than Light', "Tom Clancy's Splinter Cell Blacklist", 'Torchlight', 'Orcs Must Die! 2', 'Dying Light', 'Metro 2033', 'Natural Selection 2', 'Warhammer End Times - Vermintide', 'Borderlands', 'The Wolf Among Us', 'Mark of the Ninja', 'Saints Row The Third', 'Amnesia The Dark Descent', 'The Forest', "Sid Meier's Civilization Beyond Earth", 'Rogue Legacy', "Garry's Mod", 'Killing Floor 2', 'Sanctum', 'State of Decay', 'Dungeons of Dredmor', 'Hotline Miami', 'Armikrog', 'Sonic Generations', 'LEGO Batman 2', 'Machinarium', 'Broken Age', 'Unturned', 'Serious Sam 3 BFE', 'The Cave', 'PAYDAY 2', 'Max Payne 3', 'METAL GEAR SOLID V GROUND ZEROES', 'Brothers - A Tale of Two Sons', 'Castle Crashers', 'Thief', "Don't Starve", 'Galactic Civilizations II Ultimate Edition', 'Bulletstorm', 'Prison Architect', 'Mass Effect 2', 'Magicka', 'DmC Devil May Cry', 'Transformers Fall of Cybertron', 'Little Inferno', 'The Long Dark', 'Cities Skylines', 'Gone Home', 'The Stanley Parable', 'Undertale', 'Saints Row IV', 'ORION Prelude', 'Hardland', 'Satellite Reign', 'Guns of Icarus Online', 'Just Cause 2', 'Alien Swarm', 'Red Faction Guerrilla Steam Edition', 'Trine 2', 'Monaco', 'Age of Empires II HD Edition', 'Spec Ops The Line', 'NiGHTS into Dreams...', 'Divinity Original Sin Enhanced Edition', 'Goat Simulator', 'Sleeping Dogs', 'Crusader Kings II', 'Shadowrun Hong Kong', 'Kingdoms of Amalur Reckoning', 'Left 4 Dead', 'Crysis 2 Maximum Edition', 'Sir, You Are Being Hunted', 'Dungeon Defenders', 'Call of Juarez Gunslinger', 'Darkest Dungeon', 'Dear Esther', 'Warhammer 40,000 Dawn of War II - Chaos Rising', 'Sanctum 2', 'Awesomenauts', 'Papers, Please', 'Might & Magic Heroes VI', 'Surgeon Simulator', 'Sonic & All-Stars Racing Transformed', 'Alpha Protocol', 'Legend of Grimrock 2', 'Brtal Legend', 'Styx Master of Shadows', 'Banished', 'Age of Wonders III', 'Age of Empires III Complete Collection', 'Just Cause 2 Multiplayer Mod', 'Counter-Strike', 'The Talos Principle', 'Savage Lands', 'Dota 2', 'Counter-Strike Source', 'Outlast', 'Battlefield Bad Company 2', 'The Lord of the Rings War in the North', 'Serious Sam HD The Second Encounter', 'Gunpoint', 'Alan Wake', 'Insurgency', 'Nexuiz', 'The Binding of Isaac', "Wasteland 2 Director's Cut", 'Warhammer 40,000 Dawn of War II', 'BattleBlock Theater', 'Universe Sandbox', 'Driver San Francisco', 'DuckTales Remastered', 'Fallout', 'Nidhogg', 'Octodad Dadliest Catch', 'Portal', 'Euro Truck Simulator 2', 'Scribblenauts Unlimited', 'Amnesia A Machine for Pigs', 'Dragon Age Origins - Ultimate Edition', 'PROTOTYPE 2', 'Guacamelee! Gold Edition', 'The Swapper', 'Shadow Warrior', 'The Testament of Sherlock Holmes', 'Half-Life 2', 'The Secret of Monkey Island Special Edition', 'Deus Ex Game of the Year Edition', 'Cave Story+']
# ['Killing Floor', 'Robocraft', 'Half-Life 2 Episode One', 'PAYDAY The Heist', 'Super Meat Boy', 'Counter-Strike Condition Zero', 'DayZ', 'No More Room in Hell', 'Trove', 'Half-Life 2 Lost Coast', 'Half-Life 2 Episode Two', 'Half-Life 2 Deathmatch', 'Heroes & Generals', 'Day of Defeat Source', 'PlanetSide 2', 'War Thunder', "Don't Starve Together Beta", 'Warframe', 'Grand Theft Auto IV', 'Sniper Elite V2', 'Grand Theft Auto V', 'Arma 2 Operation Arrowhead', 'Dirty Bomb', "Mirror's Edge", 'BioShock']
#
#
# ['Counter-Strike']
# ['Counter-Strike Global Offensive', 'Dota 2', 'Team Fortress 2', 'Counter-Strike Source', 'Counter-Strike Condition Zero']
#
#
# ['Counter-Strike Global Offensive', 'Counter-Strike', 'Counter-Strike Source', 'RaceRoom Racing Experience ', 'theHunter']
# ['Dota 2', 'Killing Floor', 'DayZ', "Garry's Mod", 'The Elder Scrolls V Skyrim', 'Portal 2', 'Alien Swarm', 'Unturned', 'Day of Defeat Source', 'Portal', 'Grand Theft Auto IV', 'Terraria', 'Left 4 Dead 2', 'Arma 2 Operation Arrowhead', "Sid Meier's Civilization V", 'PAYDAY 2', 'Borderlands 2', 'Half-Life 2', 'Team Fortress 2', 'Counter-Strike Condition Zero']
#
#
# ['Counter-Strike Source', 'Counter-Strike Global Offensive', 'War Thunder', 'Call of Duty Modern Warfare 2', 'Call of Duty Black Ops II - Multiplayer', 'Left 4 Dead 2', 'Half-Life 2', 'Call of Duty Black Ops II', 'Call of Duty Black Ops II - Zombies']
# ['Heroes & Generals', 'Killing Floor', 'Alien Swarm', 'Portal 2', 'Left 4 Dead', 'Day of Defeat Source', 'Robocraft', 'Call of Duty Black Ops - Multiplayer', 'Terraria', 'Chivalry Medieval Warfare', "Sid Meier's Civilization V", 'PAYDAY 2', 'Half-Life 2 Episode One', 'PAYDAY The Heist', 'Borderlands 2', 'Team Fortress 2', 'Call of Duty Black Ops', 'Saints Row The Third', 'Dota 2', 'Counter-Strike', 'DayZ', "Garry's Mod", 'The Elder Scrolls V Skyrim', 'Call of Duty Modern Warfare 3', 'Unturned', 'Call of Duty Modern Warfare 3 - Multiplayer', 'Warframe', 'Portal', 'Half-Life 2 Lost Coast', 'Grand Theft Auto IV', 'Sniper Elite V2', 'Arma 2 Operation Arrowhead', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Fallout New Vegas', 'Half-Life 2 Episode Two']

# %% [markdown]
# On peut remarquer que pour des supports allant de 10% à 5% on obtient presque uniquement les jeux les plus joués. Ce qui n'est pas étonnant comme on n'a pas filtré selon les temps de jeux. Obtenir une recommendation par association semble donc être futile.
# On va voir s'il est possible de faire .
# On va déjà faire rentrer le temps de jeu en paramètre : Si un joueur n'a pas plus d'heure de jeu que la moyenne pour un certain jeu, on ne le prend pas en compte.

# %%
avg = played_games_orig.groupby('game')['hours_played'].apply(np.average).reset_index(name='avg_hours_played')
avg
# Out:
#                                                    game  avg_hours_played
# 0                                           007 Legends          0.700000
# 1                                             0RBITALIS          0.400000
# 2     1... 2... 3... KICK IT! (Drop That Beat Like a...          4.000000
# 3                                       10 Second Ninja          2.950000
# 4                                            10,000,000          3.600000
# ...                                                 ...               ...
# 3595                                         rymdkapsel          1.100000
# 3596                                       sZone-Online          0.977586
# 3597                          the static speaks my name          0.250000
# 3598                                          theHunter          2.493548
# 3599                                   theHunter Primal         21.475000
#
# [3600 rows x 2 columns]

# %%
#Dictionnary of average time played
avg_dict = avg.set_index('game').to_dict()['avg_hours_played']
avg_dict
# Out:
# {'007 Legends': 0.7,
#  '0RBITALIS': 0.39999999999999997,
#  '1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)': 4.0,
#  '10 Second Ninja': 2.95,
#  '10,000,000': 3.6,
#  '100% Orange Juice': 8.700000000000001,
#  '1000 Amps': 0.1,
#  '12 Labours of Hercules': 4.957142857142856,
#  '12 Labours of Hercules II The Cretan Bull': 4.2875,
#  '12 Labours of Hercules III Girl Power': 6.533333333333334,
#  '140': 1.26,
#  '15 Days': 0.5,
#  '16bit Trader': 4.45,
#  '1701 A.D. Sunken Dragon': 0.6,
#  '18 Wheels of Steel American Long Haul': 5.8,
#  '1953 NATO vs Warsaw Pact': 5.9,
#  '1Quest': 2.7,
#  '3 Stars of Destiny': 4.7,
#  '3089 -- Futuristic Action RPG': 0.3,
#  '3D Mini Golf': 1.0,
#  '3DMark': 13.377777777777778,
#  '3DMark 11': 3.0,
#  '3DMark Vantage': 21.0,
#  '4 Elements': 14.85,
#  '404Sight': 0.5285714285714286,
#  '500 Years Act 1': 3.0,
#  '60 Seconds!': 1.86,
#  '7 Days to Die': 41.586734693877546,
#  '8BitBoy': 3.4,
#  '8BitMMO': 0.4555555555555555,
#  '9 Clues 2 The Ward': 5.1,
#  '9 Clues The Secret of Serpent Creek': 2.8,
#  '9.03m': 0.3,
#  '99 Levels To Hell': 1.3800000000000001,
#  '99 Spirits': 3.9,
#  'A Bird Story': 1.657142857142857,
#  'A Game of Thrones - Genesis': 6.092307692307693,
#  'A Golden Wake': 1.2,
#  'A New Beginning - Final Cut': 7.266666666666666,
#  'A Story About My Uncle': 3.4,
#  'A Valley Without Wind': 1.1166666666666665,
#  'A Valley Without Wind 2': 0.3,
#  'A Virus Named TOM': 1.9583333333333337,
#  'A Walk in the Dark': 1.25,
#  'A-Train 8': 0.1,
#  'A.R.E.S.': 2.888888888888889,
#  'A.R.E.S. Extinction Agenda EX': 9.6,
#  'A.V.A - Alliance of Valiant Arms': 4.04074074074074,
#  'ACE - Arena Cyber Evolution': 0.5818181818181819,
#  'ACE COMBAT ASSAULT HORIZON Enhanced Edition': 3.5181818181818176,
#  'AI War Fleet Command': 3.5,
#  'AION Free-to-Play': 6.666666666666667,
#  "AKIBA'S TRIP Undead & Undressed": 12.0,
#  'APB Reloaded': 66.93623188405797,
#  'APOX': 0.4,
#  'AR-K': 0.4,
#  'ARK Survival Evolved': 86.03227848101265,
#  'AXYOS': 4.4,
#  'AZMD! Scorepocalypse ': 1.1,
#  'AaAaAA!!! - A Reckless Disregard for Gravity': 4.4799999999999995,
#  'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome': 1.1333333333333335,
#  'Abandoned Chestnut Lodge Asylum': 5.7,
#  'Abducted': 0.2,
#  'Aberoth': 0.35,
#  'Absconding Zatwor': 11.1,
#  'Absolute Drift': 1.9666666666666668,
#  'Abyss Odyssey': 3.9199999999999995,
#  'Abyss The Wraiths of Eden': 6.8,
#  'Ace of Spades': 7.340845070422536,
#  'Aces Wild Manic Brawling Action!': 0.35,
#  'Achron': 0.8666666666666667,
#  'Act of Aggression': 4.25,
#  'Action! - Gameplay Recording and Streaming': 89.66666666666667,
#  'Actual Sunlight': 1.3,
#  'AdVenture Capitalist': 43.03333333333334,
#  'Adventure Chronicles The Search For Lost Treasure': 0.7,
#  'Adventure Park': 0.9,
#  'Adventure Time  Explore the Dungeon Because I DONT KNOW!': 0.3,
#  'Adventurer Manager': 21.0,
#  'Adventures of Bertram Fiddle Episode 1 A Dreadly Business': 1.7,
#  'Adventures of Shuggy': 1.55,
#  'Aeon Command': 0.43333333333333335,
#  'Aerena': 2.1999999999999997,
#  'Afterfall InSanity - Dirty Arena Edition': 0.45,
#  'Afterfall InSanity Extended Edition': 1.861290322580645,
#  'Afterlife Empire': 0.2,
#  'Aftermath': 5.101851851851852,
#  'Agarest Generations of War': 15.6875,
#  'Agarest Zero': 10.6,
#  'Age of Chivalry': 16.724137931034484,
#  'Age of Conan Rise of the Godslayer': 4.6,
#  'Age of Conan Unchained - EU version': 20.528571428571432,
#  'Age of Empires II HD Edition': 34.2925,
#  'Age of Empires III Complete Collection': 17.133734939759034,
#  'Age of Empires Online': 83.2,
#  'Age of Mythology Extended Edition': 13.01388888888889,
#  'Age of Wonders': 16.4,
#  'Age of Wonders 2': 31.6,
#  'Age of Wonders III': 35.040625,
#  'Age of Wonders Shadow Magic': 17.9,
#  'Aggression Europe Under Fire': 0.6,
#  'Agricultural Simulator 2011 Extended Edition': 0.1,
#  'Agricultural Simulator 2013 Steam Edition': 23.2,
#  'Aion': 10.35,
#  'Aion Collectors Edition': 22.0,
#  'Air Brawl': 2.45,
#  'Air Conflicts - Secret Wars': 1.65,
#  'Air Conflicts Pacific Carriers': 2.533333333333333,
#  'AirBuccaneers': 0.78,
#  'AirMech': 12.123255813953488,
#  'Airline Tycoon 2': 6.2,
#  'Airline Tycoon Deluxe': 0.6,
#  'Airport Madness World Edition': 9.0,
#  'Airport Simulator 2014': 8.5,
#  'Akane the Kunoichi': 1.65,
#  'Akaneiro Demon Hunters': 0.4,
#  'Akuatica': 0.4,
#  'Alan Wake': 11.875,
#  "Alan Wake's American Nightmare": 3.4416666666666664,
#  'Albino Lullaby Episode 1': 1.5,
#  'Alchemy Mysteries Prague Legends': 3.9799999999999995,
#  'Alex Hunter - Lord of the Mind': 2.7,
#  'Alganon': 0.5,
#  'Alice Madness Returns': 8.211111111111112,
#  'Alien Breed 2 Assault': 5.142857142857143,
#  'Alien Breed 3 Descent': 9.066666666666666,
#  'Alien Breed Impact': 8.58,
#  'Alien Isolation': 11.580645161290322,
#  'Alien Rage - Unlimited': 2.88,
#  'Alien Shooter Revisited': 0.1,
#  'Alien Shooter Vengeance': 4.433333333333333,
#  'Alien Swarm': 5.2076124567474045,
#  'Aliens Colonial Marines': 9.963636363636363,
#  'Aliens versus Predator Classic 2000': 1.73,
#  'Aliens vs. Predator': 12.493150684931507,
#  'All Is Dust': 1.4333333333333333,
#  'All Zombies Must Die!': 4.433333333333334,
#  'Alone in the Dark': 0.4,
#  'Alpha Kimori Episode One ': 1.8,
#  'Alpha Prime': 0.5666666666666668,
#  'Alpha Protocol': 3.52,
#  'Alter World': 0.1,
#  'Altitude': 5.453846153846154,
#  'Always Sometimes Monsters': 4.758333333333334,
#  'Amazing Adventures Around the World': 12.0,
#  'Amazing Adventures The Lost Tomb': 3.3,
#  'Amazing Princess Sarah': 0.8,
#  'Amazing World': 1.8500000000000003,
#  "America's Army 3": 10.618750000000002,
#  "America's Army Proving Grounds": 27.003773584905662,
#  'American Conquest': 0.3,
#  'American Conquest - Fight Back': 0.4,
#  'Amnesia A Machine for Pigs': 4.408,
#  'Amnesia Memories': 4.9,
#  'Amnesia The Dark Descent': 5.082300884955753,
#  'Among Ripples': 0.42500000000000004,
#  'Among the Sleep': 1.7333333333333334,
#  'Ampu-Tea': 0.8666666666666666,
#  'An Assassin in Orlandes': 5.0,
#  'Anachronox': 0.1,
#  'Analogue A Hate Story': 3.242857142857143,
#  'Anarchy Arcade': 1.3800000000000001,
#  'Ancient Planet': 2.5,
#  'Ancient Space': 27.0,
#  'And Yet It Moves': 1.3066666666666662,
#  'Angels Fall First': 5.066666666666666,
#  'Angels of Fasaria Version 2.0': 9.9,
#  'Angry Birds Space': 2.7,
#  'Angry Video Game Nerd Adventures': 1.9700000000000002,
#  'Angvik': 0.3,
#  'Anna - Extended Edition': 3.5818181818181816,
#  "Anna's Quest": 9.25,
#  'Anno 1404': 14.222222222222221,
#  'Anno 1404 Venice': 16.75,
#  'Anno 2070': 29.42,
#  'Anno 2205': 22.0,
#  'Anno Online': 93.025,
#  'Anodyne': 3.0666666666666664,
#  'Anomaly 2': 1.52,
#  'Anomaly Korea': 0.9,
#  'Anomaly Warzone Earth': 2.0945945945945947,
#  'Anomaly Warzone Earth Mobile Campaign': 2.1,
#  'Another Perspective': 0.3,
#  'Another World': 1.24,
#  'Anoxemia': 6.15,
#  'Antichamber': 2.7880000000000003,
#  'Antisquad': 16.2,
#  'Aperture Tag The Paint Gun Testing Initiative': 1.8,
#  'Apollo4x': 3.8,
#  'Apotheon': 2.92,
#  'Apotheon Arena': 0.9000000000000001,
#  'Aqua Kitty - Milk Mine Defender': 0.30000000000000004,
#  'AquaNox': 0.44999999999999996,
#  'Aquaria': 4.285714285714286,
#  'Arcadia': 0.6,
#  'Arcane Worlds': 0.2,
#  'ArcaniA': 5.97,
#  'ArcheAge': 27.742499999999996,
#  'Archeblade': 4.357627118644068,
#  'ArchonClassic': 1.3,
#  'Arctic Combat': 6.133333333333334,
#  'Arma 2': 5.615646258503402,
#  'Arma 2 British Armed Forces': 0.2333333333333333,
#  'Arma 2 DayZ Mod': 2.510169491525424,
#  'Arma 2 Free': 0.5333333333333333,
#  'Arma 2 Operation Arrowhead': 49.8925925925926,
#  'Arma 2 Operation Arrowhead Beta (Obsolete)': 6.565517241379309,
#  'Arma 2 Private Military Company': 0.7714285714285715,
#  'Arma 3': 153.22101910828025,
#  'Arma Cold War Assault': 1.403703703703704,
#  'Arma Combat Operations': 33.06666666666667,
#  'Arma Tactics': 1.94,
#  'Armada 2526': 0.6,
#  'Armello': 7.0,
#  'Armikrog': 4.7,
#  'Arms Dealer': 1.9,
#  'ArtRage Studio Pro': 9.3,
#  'Artemis Spaceship Bridge Simulator': 2.8333333333333335,
#  'Arx Fatalis': 12.459999999999999,
#  'Ascend Hand of Kul': 5.663636363636364,
#  'Ascendant': 5.0,
#  'Ashes of the Singularity': 0.7,
#  "Assassin's Creed": 11.538888888888888,
#  "Assassin's Creed Brotherhood": 25.035897435897436,
#  "Assassin's Creed Freedom Cry": 2.966666666666667,
#  "Assassin's Creed II": 27.900000000000002,
#  "Assassin's Creed III": 45.45357142857143,
#  "Assassin's Creed IV Black Flag": 59.82037037037038,
#  "Assassin's Creed Revelations": 38.17,
#  "Assassin's Creed Rogue": 62.0,
#  "Assassin's Creed Syndicate": 32.13333333333333,
#  'Assassins Creed Chronicles China': 4.8,
#  'Assassins Creed Unity': 20.176470588235293,
#  'Assault Android Cactus': 1.45,
#  'Assetto Corsa': 15.738888888888889,
#  'Astebreed': 0.4,
#  'Asteria': 1.0,
#  'Asteroids Outpost': 0.3,
#  'Astro Lords': 0.15000000000000002,
#  'Atlantica Online': 8.2,
#  'Atom Zombie Smasher ': 5.831578947368421,
#  'Audiosurf': 8.09875,
#  'Audiosurf 2': 15.757142857142858,
#  'Audition Online': 2.0599999999999996,
#  'Auditorium': 0.45,
#  'Aura Fate of the Ages': 3.5999999999999996,
#  'Aura Kingdom': 5.107317073170731,
#  'Autobahn Police Simulator': 0.9500000000000001,
#  'Autocraft': 5.1,
#  'Automation - The Car Company Tycoon Game': 6.2,
#  'Avadon 2 The Corruption': 2.9,
#  'Avadon The Black Fortress': 0.3333333333333333,
#  'Avernum 4': 228.0,
#  'Avernum 5': 222.0,
#  'Avernum 6': 80.0,
#  'Avernum Escape From the Pit': 85.66666666666667,
#  'Aveyond 3-1 Lord of Twilight': 1.2,
#  'Aveyond 3-2 Gates of Night': 0.3,
#  'Awesomenauts': 22.127941176470586,
#  'Axiom Verge': 7.574999999999999,
#  "Axis Game Factory's AGFPRO 3.0": 2.2399999999999998,
#  'Azure Striker Gunvolt': 5.5,
#  'B.U.T.T.O.N.': 0.1,
#  'BAD END': 3.8,
#  'BEEP': 1.4249999999999998,
#  'BIT.TRIP BEAT': 1.6615384615384616,
#  'BIT.TRIP CORE': 0.1,
#  'BIT.TRIP FATE': 0.25,
#  'BIT.TRIP Presents... Runner2 Future Legend of Rhythm Alien': 2.3692307692307693,
#  'BIT.TRIP RUNNER': 1.8399999999999999,
#  'BIT.TRIP VOID': 0.4,
#  'BLOCKADE 3D': 5.683333333333334,
#  'BRAINPIPE A Plunge to Unhumanity': 1.8666666666666665,
#  'BRINK': 7.421875,
#  'Babel Rising': 0.2,
#  'Back to Bed': 1.6,
#  'Back to Dinosaur Island ': 1.5285714285714285,
#  "Back to the Future Ep 1 - It's About Time": 2.3000000000000003,
#  'Back to the Future Ep 2 - Get Tannen!': 2.2,
#  'Back to the Future Ep 3 - Citizen Brown': 2.7,
#  'Back to the Future Ep 4 - Double Visions': 2.6,
#  'Back to the Future Ep 5 - OUTATIME': 2.766666666666667,
#  'Bad Hotel': 10.0,
#  'Bad Rats': 2.253846153846154,
#  "Baldur's Gate Enhanced Edition": 134.5608695652174,
#  "Baldur's Gate II Enhanced Edition": 475.2555555555556,
#  'Ballad of Solar': 10.1,
#  'Ballpoint Universe Infinite': 1.0333333333333332,
#  'Banished': 30.24137931034483,
#  "Bard's Gold": 119.0,
#  'Bardbarian': 6.949999999999999,
#  'Basement': 23.233333333333334,
#  'Bastion': 6.09252336448598,
#  'Batla': 3.02,
#  'Batman Arkham Asylum': 21.400000000000002,
#  'Batman Arkham Asylum GOTY Edition': 12.676363636363636,
#  'Batman Arkham City': 22.6,
#  'Batman Arkham City GOTY': 19.05137614678899,
#  'Batman Arkham Knight': 15.099999999999998,
#  'Batman Arkham Origins': 19.916326530612245,
#  'Batman Arkham Origins Blackgate - Deluxe Edition': 4.766666666666667,
#  'Battle Academy': 14.6,
#  'Battle Academy 2 Eastern Front': 0.1,
#  'Battle Battalions': 0.275,
#  'Battle Brothers': 1.5,
#  'Battle Group 2': 2.6,
#  'Battle Islands': 34.87272727272727,
#  'Battle Los Angeles': 4.1,
#  'Battle Nations': 131.4,
#  'Battle for Graxia': 1.2666666666666666,
#  'Battle of Empires  1914-1918': 24.400000000000002,
#  'Battle vs Chess': 5.0,
#  'BattleBlock Theater': 5.9028301886792445,
#  'BattleSpace': 0.7,
#  'Battlefield 2': 13.664285714285715,
#  'Battlefield Bad Company 2': 60.16756756756757,
#  'Battlegrounds of Eldhelm': 0.4,
#  'Battlepaths': 5.319999999999999,
#  'Battleplan American Civil War': 3.1,
#  'Battlestations Midway': 6.175,
#  'Battlestations Pacific': 15.320000000000002,
#  'BeamNG.drive': 6.8500000000000005,
#  'Beast Boxing Turbo': 0.95,
#  'Beasts of Prey': 16.825,
#  'Beat Hazard': 5.644117647058825,
#  'Beatbuddy Tale of the Guardians': 2.433333333333333,
#  'Bedlam': 3.4,
#  'Before the Echo': 1.9199999999999995,
#  'Bejeweled 2 Deluxe': 0.7999999999999999,
#  'Bejeweled 3': 15.26428571428571,
#  'Bejeweled Deluxe': 1.0,
#  'Ben There, Dan That!': 1.3199999999999998,
#  'Bermuda': 1.9,
#  'Besiege': 13.753846153846153,
#  'Betrayer': 2.4166666666666665,
#  'Better Late Than DEAD': 3.4,
#  'Beware Planet Earth': 2.2,
#  'Beyond Divinity': 0.75,
#  'Beyond Eyes': 1.5,
#  'Beyond Good & Evil': 4.733333333333333,
#  'Beyond Space': 12.6,
#  "Bientt l't": 0.4,
#  'Big Brain Wolf': 0.5,
#  'Big Money! Deluxe': 3.0,
#  'Big Pharma': 9.466666666666667,
#  'Binary Domain': 4.8999999999999995,
#  'BioShock': 7.616783216783215,
#  'BioShock 2': 7.527272727272727,
#  'BioShock Infinite': 17.401415094339622,
#  'Bionic Commando': 1.2,
#  'Bionic Commando Rearmed': 0.27499999999999997,
#  'Bionic Dues': 1.8,
#  'Black Fire': 1.45,
#  'Black Ice': 1.1,
#  'Black Ink': 79.76666666666667,
#  'Black Mesa': 17.1625,
#  'Black Mirror': 0.8,
#  'Black Sails': 1.8,
#  "Black Viper Sophia's Fate": 0.2,
#  'Blackguards': 19.816666666666666,
#  'Blackguards 2': 27.833333333333332,
#  'Blacklight Retribution': 15.570370370370373,
#  'Blacklight Tango Down': 0.8999999999999999,
#  'Blackwell Convergence': 0.3,
#  'Blade Symphony': 11.116666666666667,
#  'Blades of Time': 8.116666666666665,
#  'Blaster Shooter GunGuy!': 1.8,
#  'BlazBlue Calamity Trigger': 3.05,
#  'BlazBlue Continuum Shift Extend': 77.93333333333334,
#  'BlazeRush': 0.1,
#  'Blazing Angels 2 Secret Missions of WWII': 6.266666666666667,
#  'Blazing Angels Squadrons of WWII': 7.6,
#  'Bleed': 2.32,
#  'Blender 2.76b': 0.8833333333333333,
#  'Blitzkrieg 2 Anthology': 7.266666666666667,
#  'Blitzkrieg Anthology': 2.8333333333333335,
#  'Blob From Space': 2.9,
#  'Block N Load': 5.632608695652174,
#  'Block Story': 15.7,
#  'Blockland': 4.2,
#  'Blocks That Matter': 2.213333333333333,
#  'Blockscape': 0.5,
#  'Blockstorm': 1.4428571428571428,
#  'Blood Bowl 2': 41.28333333333334,
#  'Blood Bowl Chaos Edition': 94.0153846153846,
#  'Blood Bowl Dark Elves Edition': 13.9,
#  'Blood Bowl Legendary Edition': 27.611764705882354,
#  'Blood Knights': 2.5,
#  'Blood Omen 2 Legacy of Kain': 1.45,
#  'Blood One Unit Whole Blood': 1.1666666666666667,
#  'Blood of Old': 3.775,
#  'Blood of the Werewolf': 0.5,
#  'BloodLust Shadowhunter': 0.3,
#  'BloodRayne': 6.6,
#  'BloodRayne 2': 2.9,
#  'BloodRayne Betrayal': 1.6500000000000001,
#  'BloodRealm Battlegrounds': 1.633333333333333,
#  'Bloodbath Kavkaz': 4.9,
#  'Bloodline Champions': 12.104166666666666,
#  'Bloodwood Reload': 0.2,
#  'Bloody Good Time': 9.533333333333333,
#  'Bloody Trapland': 1.4076923076923078,
#  'Bloons TD5': 21.200000000000003,
#  'Blue Rose': 3.2,
#  'Blur': 7.142857142857143,
#  'Bob Came in Pieces': 0.575,
#  'Bob Was Hungry': 6.5,
#  'Boid': 8.9,
#  'Boo Bunny Plague': 2.3,
#  'BookWorm Adventures Volume 2': 60.25,
#  'BookWorm Deluxe': 6.9,
#  'Bookworm Adventures Deluxe': 18.725,
#  'Booster Trooper': 0.7000000000000001,
#  'Borderlands': 32.48493150684931,
#  'Borderlands 2': 58.72512953367876,
#  'Borderlands 2 RU': 48.065000000000005,
#  'Borderlands The Pre-Sequel': 37.527631578947364,
#  'Borderless Gaming': 13.1,
#  'Borealis': 1.8250000000000002,
#  'Boring Man - Online Tactical Stickman Combat': 3.638095238095237,
#  'Boson X': 4.7,
#  'Botanicula': 3.08125,
#  'Bound By Flame': 12.242857142857144,
#  'Braid': 2.8875,
#  'Brawlhalla': 7.055384615384615,
#  'Breach': 4.266666666666667,
#  'Breach & Clear': 1.9,
#  'Break Into Zatwor': 1.6666666666666667,
#  'Breath of Death VII ': 1.0125,
#  'Breezeblox': 48.0,
#  'Brick-Force': 1.229268292682927,
#  'Bridge Constructor': 3.516666666666667,
#  'Bridge Constructor Medieval': 1.7,
#  'Bridge It (plus)': 1.3,
#  'Bridge Project': 1.457142857142857,
#  'Brilliant Bob': 6.950000000000001,
#  'Broforce': 26.476923076923075,
#  'Broken Age': 9.83125,
#  "Broken Sword 1 - Shadow of the Templars Director's Cut": 5.4399999999999995,
#  'Broken Sword 2 - the Smoking Mirror Remastered': 5.7,
#  'Broken Sword 3 - the Sleeping Dragon': 0.4,
#  'Broken Sword 4 - the Angel of Death': 21.0,
#  "Broken Sword 5 - the Serpent's Curse": 14.300000000000002,
#  'Brothers - A Tale of Two Sons': 2.3899999999999997,
#  "Brothers in Arms Hell's Highway": 5.549999999999999,
#  'Brothers in Arms Road to Hill 30': 8.25,
#  'Brtal Legend': 6.063888888888888,
#  'Buccaneer The Pursuit of Infamy': 7.2,
#  'Build-A-Lot': 8.9,
#  'Build-A-Lot 2': 5.2,
#  'Build-A-Lot 4': 97.0,
#  'Bullet Heaven 2': 5.3,
#  'Bulletstorm': 13.034782608695656,
#  'Bully Scholarship Edition': 10.22608695652174,
#  'Bunch Of Heroes': 0.8,
#  'Burgers': 8.3,
#  'Burn Zombie Burn': 1.8,
#  'Burnout Paradise The Ultimate Box': 5.731325301204819,
#  'Burstfire': 1.6500000000000001,
#  'Bus Driver': 0.21666666666666667,
#  'Bus-Simulator 2012': 3.2,
#  "Buzz Aldrin's Space Program Manager": 4.5,
#  'C9': 0.45,
#  'CAFE 0 ~The Drowned Mermaid~': 3.0,
#  'CID The Dummy': 4.4,
#  'CRYENGINE': 0.1,
#  'CRYPTARK': 0.7,
#  "Cabela's African Adventures": 0.7,
#  "Cabela's Big Game Hunter Pro Hunts": 6.7,
#  "Cabela's Dangerous Hunts 2013": 0.8,
#  "Cabela's Hunting Expeditions": 3.5,
#  'Cabelas Trophy Bucks': 3.4,
#  'CaesarIA': 0.6,
#  'Call of Cthulhu Dark Corners of the Earth': 12.2,
#  'Call of Duty': 2.9666666666666663,
#  'Call of Duty 2': 5.1875,
#  'Call of Duty 4 Modern Warfare': 20.39666666666667,
#  'Call of Duty Advanced Warfare': 10.290384615384617,
#  'Call of Duty Advanced Warfare - Multiplayer': 50.76065573770492,
#  'Call of Duty Black Ops': 17.07488986784141,
#  'Call of Duty Black Ops - Multiplayer': 86.58838383838383,
#  'Call of Duty Black Ops - Multiplayer OSX': 31.35,
#  'Call of Duty Black Ops - OSX': 10.6,
#  'Call of Duty Black Ops II': 12.56725663716814,
#  'Call of Duty Black Ops II - Multiplayer': 91.49867549668873,
#  'Call of Duty Black Ops II - Zombies': 12.077391304347827,
#  'Call of Duty Black Ops III': 36.3051282051282,
#  'Call of Duty Ghosts': 9.115714285714285,
#  'Call of Duty Ghosts - Multiplayer': 54.351428571428585,
#  'Call of Duty Modern Warfare 2': 29.075420875420868,
#  'Call of Duty Modern Warfare 2 - Multiplayer': 144.3639175257732,
#  'Call of Duty Modern Warfare 3': 25.799052132701423,
#  'Call of Duty Modern Warfare 3 - Multiplayer': 105.11734693877551,
#  'Call of Duty United Offensive': 93.525,
#  'Call of Duty World at War': 37.99264705882353,
#  'Call of Juarez': 6.0,
#  'Call of Juarez Bound in Blood': 5.6000000000000005,
#  'Call of Juarez Gunslinger': 7.261702127659572,
#  'Call of Juarez The Cartel': 6.549999999999999,
#  'Call of Tomsk-7': 1.5,
#  'Call to Arms': 25.066666666666666,
#  'Camera Obscura': 5.025,
#  'CameraBag 2': 2.5,
#  'Cannon Brawl': 1.7999999999999998,
#  'Cannons Lasers Rockets': 0.6333333333333334,
#  'Canyon Capers': 2.891666666666666,
#  'Capsized': 1.4,
#  'Captain Forever Remix': 22.0,
#  'Car Mechanic Simulator 2014': 2.971428571428571,
#  'Car Mechanic Simulator 2015': 8.507692307692308,
#  'Card City Nights': 1.4,
#  'Card Hunter': 3.6149999999999998,
#  'Cards and Castles': 0.85,
#  'Cargo Commander': 2.3333333333333335,
#  'Cargo! - The quest for gravity': 7.0,
#  'Caribbean!': 17.3,
#  'Carmageddon 2 Carpocalypse Now': 6.45,
#  'Carmageddon Max Pack': 2.8,
#  'Carmageddon Reincarnation': 5.975,
#  'Carnage Racing': 0.1,
#  'Carpe Diem': 0.26666666666666666,
#  'Carrier Command Gaea Mission': 2.2333333333333334,
#  'Cast of the Seven Godsends': 7.4,
#  'Castaway Paradise': 6.8,
#  'Caster': 1.3599999999999999,
#  'Castle': 1.3,
#  'Castle Crashers': 6.554248366013072,
#  'Castle In The Darkness': 10.6,
#  'Castle Never Judge a Book by its Cover': 0.8,
#  'Castle Story': 10.94,
#  'Castle of Illusion': 12.4,
#  'CastleMiner Z': 4.857142857142857,
#  'CastleStorm': 5.915384615384616,
#  'Castlevania Lords of Shadow  Mirror of Fate HD': 0.5,
#  'Castlevania Lords of Shadow - Ultimate Edition': 5.66,
#  'Castlevania Lords of Shadow 2': 18.057142857142857,
#  'Cat Goes Fishing': 0.5,
#  'Catmouth Island': 2.6,
#  'Cave Story+': 9.875862068965514,
#  'Chains': 2.5833333333333335,
#  'Chainsaw Warrior': 4.25,
#  'Chainsaw Warrior Lords of the Night': 3.55,
#  'Champions Online': 39.34761904761905,
#  'Championship Manager 2008': 0.4,
#  'Championship Manager 2010': 10.7,
#  'Chantelise': 0.4666666666666666,
#  'Chaos Domain': 0.16666666666666666,
#  'Chaos Heroes Online': 0.3333333333333333,
#  'Chaos on Deponia': 8.17,
#  'Chaser': 4.25,
#  'Cherry Tree High Comedy Club': 3.1,
#  'Cherry Tree High I! My! Girls!': 5.3,
#  'Chessmaster': 1.8,
#  'Child of Light': 7.790909090909091,
#  'Children of the Nile': 0.5,
#  'Children of the Nile Alexandria': 2.9,
#  'Chime': 2.6285714285714286,
#  'Chip': 2.142857142857143,
#  "Chip's Challenge 2": 0.6,
#  'Chivalry Medieval Warfare': 20.540932642487046,
#  'Chocolatier Decadence by Design': 90.0,
#  'Choice Chamber': 5.3,
#  'Choice of Robots': 2.1,
#  'Choice of the Deathless': 2.2,
#  "Chris Sawyer's Locomotion": 2.6,
#  'Chroma Squad': 6.7,
#  'Chrome': 0.3,
#  'Chrome Specforce': 0.1,
#  'Chronicles of a Dark Lord Episode 1 Tides of Fate Complete': 4.949999999999999,
#  'Chuzzle Deluxe': 6.3,
#  'Cinders': 3.1500000000000004,
#  'Circuits': 2.1,
#  'Citadels': 0.5,
#  'Cities Skylines': 27.836521739130436,
#  'Cities XL': 2.7,
#  'Cities XL - Limited Edition': 0.95,
#  'Cities XL 2011': 10.87142857142857,
#  'Cities XL 2012': 42.90909090909091,
#  'Cities XL Platinum': 11.2,
#  'Cities XXL': 16.425,
#  'Cities in Motion': 23.6,
#  'Cities in Motion 2': 3.994736842105263,
#  'City Life 2008': 3.1,
#  'City of Heroes': 7.6,
#  'City of Steam Arkadia': 1.16,
#  'CivCity Rome': 3.0,
#  'Civil War II': 0.2,
#  'Claire': 1.2,
#  'Clash of Puppets': 2.9,
#  'Clergy Splode': 0.4,
#  'Clicker Heroes': 89.84305555555555,
#  'Clickr': 3.0,
#  'Clickteam Fusion 2.5': 0.3,
#  "Clive Barker's Jericho": 7.949999999999999,
#  'Clockwork Empires': 8.5,
#  'Clockwork Tales Of Glass and Ink': 3.6,
#  'Close Combat - Gateway to Caen': 1.0,
#  'Close Your Eyes': 1.9000000000000001,
#  'Closure': 3.3000000000000003,
#  'Cloud Chamber': 22.0,
#  'Cloudberry Kingdom': 7.2,
#  'Cloudbuilt': 0.35,
#  'Cloudy with a Chance of Meatballs': 4.9,
#  'Clown House (Palyao Evi)': 0.21428571428571427,
#  'Clutch': 1.0,
#  'Cobi Treasure Deluxe': 1.05,
#  'Codename CURE': 3.7676470588235293,
#  'Codename Gordon': 0.3909090909090909,
#  'Codename Panzers - Cold War': 3.15,
#  'Coffin Dodgers': 2.2,
#  'Cognition An Erica Reed Thriller': 3.5,
#  'Cogs': 2.2199999999999998,
#  'Coil': 0.3,
#  'Coin Crypt': 3.1999999999999997,
#  'Colin McRae Rally': 3.3000000000000003,
#  'Collapse': 1.9500000000000002,
#  'Colonial Conquest': 0.3,
#  'Color Symphony': 0.26,
#  'ComaMortuary': 0.95,
#  'Comanche 4': 22.0,
#  'Combat Arms': 18.2,
#  'Combat Wings Battle of Britain': 0.19999999999999998,
#  "Command and Conquer 3 Kane's Wrath": 11.483333333333333,
#  'Command and Conquer 3 Tiberium Wars': 9.283333333333335,
#  'Command and Conquer 4 Tiberian Twilight': 12.378947368421052,
#  'Command and Conquer Red Alert 3': 18.526923076923076,
#  'Command and Conquer Red Alert 3 - Uprising': 7.246666666666667,
#  'Commander Conquest of the Americas': 2.4,
#  'Commander Conquest of the Americas Gold': 0.35,
#  'Commander Keen Complete Pack': 1.725,
#  'Commando Jack': 1.8333333333333333,
#  'Commandos 2 Men of Courage': 3.5545454545454547,
#  'Commandos 3 Destination Berlin': 0.5,
#  'Commandos Behind Enemy Lines': 3.266666666666666,
#  'Commandos Beyond the Call of Duty': 0.2,
#  'Community College Hero Trial by Fire': 8.1,
#  'Company of Heroes': 9.841935483870968,
#  'Company of Heroes (New Steam Version)': 19.495238095238097,
#  'Company of Heroes 2': 22.471264367816094,
#  'Company of Heroes Europe at War': 12.6,
#  'Company of Heroes Opposing Fronts': 16.656000000000002,
#  'Company of Heroes Tales of Valor': 13.112121212121213,
#  'Condemned Criminal Origins': 0.3,
#  'Conflict Denied Ops': 5.7,
#  'Confrontation': 0.6,
#  'Coniclysm': 0.3,
#  'Conquest of Champions': 2.4,
#  'Constant C': 1.2,
#  'Construct 2 Free': 2.5571428571428574,
#  'Construction-Simulator 2015': 25.699999999999996,
#  'Contagion': 4.077551020408164,
#  'Containment The Zombie Puzzler': 2.3,
#  'Contraption Maker': 6.6,
#  'Contrast': 4.1,
#  'Controller Companion': 1.2,
#  'Convoy': 5.25,
#  'Cook, Serve, Delicious!': 10.090909090909092,
#  'Copa Petrobras de Marcas': 0.40625,
#  'Corporate Lifestyle Simulator': 0.6,
#  'Cortex Command': 0.8166666666666668,
#  'Cosmic DJ': 2.3,
#  'Cosmic Osmo': 0.2,
#  'Cosmonautica': 12.433333333333332,
#  'Cosmophony': 3.5,
#  'Cossacks Art of War': 33.0,
#  'Cossacks Back to War': 9.875,
#  'Cossacks European Wars': 3.5,
#  'Cossacks II Battle for Europe': 3.05,
#  'Cossacks II Napoleonic Wars': 1.8,
#  'Costume Quest': 4.082352941176471,
#  'Counter-Strike': 236.37517605633803,
#  'Counter-Strike Condition Zero': 35.33333333333333,
#  'Counter-Strike Condition Zero Deleted Scenes': 4.448936170212765,
#  'Counter-Strike Global Offensive': 234.40203340595497,
#  'Counter-Strike Nexon Zombies': 10.946195652173913,
#  'Counter-Strike Source': 134.37132867132868,
#  'Cradle': 11.633333333333333,
#  'Craft The World': 52.61333333333333,
#  'Crash Time II': 1.542857142857143,
#  'Crawl': 26.0,
#  'Crayon Physics Deluxe': 0.4652173913043477,
#  'Crazy Machines': 1.3,
#  'Crazy Machines 2': 3.775,
#  'Crazy Plant Shop': 2.0,
#  'Crazy Taxi': 0.6,
#  'CreaVures': 1.6,
#  'Creativerse': 8.200000000000001,
#  'Creeper World 3 Arc Eternal': 6.05,
#  'Cricket Captain 2014': 14.1,
#  'Cricket Revolution': 19.2,
#  'CrimeCraft GangWars': 1.5,
#  'Crimsonland': 8.6,
#  'Crimzon Clover  WORLD IGNITION': 1.9000000000000001,
#  'Critical Mass': 0.1,
#  'Critter Crunch': 0.2,
#  'CroNix': 1.3777777777777775,
#  'Crossfire Europe': 1.3249999999999997,
#  'Crouching Pony Hidden Dragon': 0.3,
#  'Crowntakers': 0.2,
#  'Crusader Kings Complete': 2.8,
#  'Crusader Kings II': 118.69342105263159,
#  'Crusaders Thy Kingdom Come': 1.5,
#  'Crusaders of the Lost Idols': 88.41428571428573,
#  'Cry of Fear': 1.8749999999999998,
#  'Cryostasis': 6.033333333333334,
#  'Crypt of the NecroDancer': 22.09375,
#  'Crysis': 6.910909090909091,
#  'Crysis 2': 22.342857142857145,
#  'Crysis 2 Maximum Edition': 6.886516853932584,
#  'Crysis Warhead': 8.278260869565218,
#  'Crysis Wars': 1.7866666666666666,
#  'Crystals of Time': 1.85,
#  'Cthulhu Saves the World ': 2.7874999999999996,
#  'CubeGun': 3.1999999999999997,
#  'Cubemen': 2.4375,
#  'Cubemen 2': 7.5,
#  'Cubic Castles': 3.6965517241379313,
#  'Cubot': 0.5,
#  'Cultures - Northland': 194.0,
#  'Curse The Eye of Isis': 0.2,
#  'Curse of Mermos': 0.65,
#  'Cyto': 3.4,
#  'D.I.P.R.I.P. Warm Up': 3.6285714285714286,
#  'D.U.S.T.': 0.1,
#  "D4 Dark Dreams Don't Die": 0.5,
#  'DARK': 6.9,
#  'DARK SOULS II': 87.23661971830985,
#  'DARK SOULS II Scholar of the First Sin': 51.25151515151515,
#  'DC Universe Online': 30.355194805194802,
#  'DCS Black Shark': 4.2,
#  'DCS World': 2.3874999999999997,
#  'DEFCON': 1.7272727272727275,
#  'DETOUR': 1.44,
#  'DLC Quest': 2.8166666666666664,
#  'DOOM 3': 3.535,
#  'DOOM 3 BFG Edition': 16.895652173913046,
#  'DOOM 3 Resurrection of Evil': 2.7199999999999998,
#  'DOOM II Hell on Earth': 3.4555555555555553,
#  'DRAGON BALL XENOVERSE': 39.196875000000006,
#  'DRAKERZ-Confrontation': 1.9,
#  'DUNGEONS - Steam Special Edition': 10.355555555555554,
#  'DUNGEONS - The Dark Lord (Steam Special Edition)': 5.42,
#  'DYNASTY WARRIORS 8 Xtreme Legends Complete Edition': 20.114285714285717,
#  'Daikatana': 0.44999999999999996,
#  'Damnation': 0.2,
#  'Damnation City of Death': 1.0,
#  'Damned': 2.4899999999999998,
#  'Dangerous High School Girls in Trouble!': 0.55,
#  'Dangerous Waters': 0.5,
#  'Dark Arcana The Carnival': 1.6,
#  'Dark Echo': 0.1,
#  'Dark Fall 1 The Journal': 0.5,
#  'Dark Fall Lost Souls': 3.0,
#  'Dark Messiah of Might & Magic Multi-Player': 52.77272727272728,
#  'Dark Messiah of Might & Magic Single Player': 7.784210526315792,
#  'Dark Souls Prepare to Die Edition': 43.07727272727273,
#  'Dark Void': 0.4,
#  'Dark Void Zero': 0.2,
#  'DarkEnd': 2.3,
#  'DarkStar One': 13.966666666666667,
#  'Darkest Dungeon': 21.11621621621622,
#  'Darkest Hour A Hearts of Iron Game': 30.900000000000002,
#  "Darkest Hour Europe '44-'45": 22.8,
#  'Darkout': 1.0,
#  'Darksiders': 13.131868131868131,
#  'Darksiders II': 19.14626865671642,
#  'Darksiders II Deathinitive Edition': 2.4,
#  'Darkspore': 25.166666666666668,
#  'Darkstone': 18.6,
#  'Darkwind War on Wheels': 0.13999999999999999,
#  'Darwinia': 2.5833333333333335,
#  'David.': 0.2,
#  'Dawn of Discovery': 9.100000000000001,
#  'Dawn of Discovery - Venice': 36.516666666666666,
#  "Day One Garry's Incident": 1.525,
#  'Day of Defeat': 14.377659574468085,
#  'Day of Defeat Source': 29.15843373493976,
#  'DayZ': 82.5829268292683,
#  'Daylight': 2.3666666666666667,
#  'Dead Bits': 2.0736842105263156,
#  'Dead Effect': 1.0000000000000002,
#  'Dead Horde': 1.0499999999999998,
#  'Dead Island': 13.912087912087912,
#  'Dead Island Epidemic': 5.84251968503937,
#  'Dead Island Riptide': 11.952830188679245,
#  "Dead Mountaineer's Hotel": 0.9,
#  'Dead Pixels': 0.5571428571428572,
#  'Dead Realm': 5.133333333333333,
#  'Dead Rising 2': 6.080952380952381,
#  'Dead Rising 2 Off the Record': 12.899999999999999,
#  'Dead Rising 3': 12.3,
#  'Dead Space': 5.036923076923077,
#  'Dead Space 2': 10.033333333333335,
#  'Dead State': 24.1,
#  'Dead or Alive 5 Last Round': 16.3,
#  'DeadCore': 2.75,
#  'Deadbreed': 2.8,
#  'Deadfall Adventures': 2.7000000000000006,
#  'Deadlight': 2.857894736842105,
#  'Deadlings - Rotten Edition': 2.5,
#  'Deadly 30': 2.7000000000000006,
#  "Deadly Premonition The Director's Cut": 2.9,
#  'Deadly Profits': 3.4,
#  'Deadpool': 10.076923076923077,
#  'Dear Esther': 1.0354838709677419,
#  'Death Rally': 5.966666666666666,
#  'Death Skid Marks': 0.3,
#  'DeathSpank': 10.8,
#  'DeathSpank Thongs Of Virtue': 6.033333333333334,
#  'Deathmatch Classic': 0.7406250000000001,
#  'Deathtrap': 1.5999999999999999,
#  'Decay - The Mare': 5.0,
#  'Deepworld': 0.5000000000000001,
#  'Defend Your Life': 1.9,
#  "Defender's Quest Valley of the Forgotten": 6.125,
#  'Defense Grid 2': 9.246153846153845,
#  'Defense Grid 2 A Matter of Endurance': 2.3,
#  'Defense Grid The Awakening': 18.434146341463418,
#  'Defiance': 15.41505376344086,
#  'Defy Gravity': 1.3769230769230771,
#  'Delta Force 2': 3.3,
#  'Delta Force Black Hawk Down': 0.6,
#  'Delta Force Black Hawk Down - Team Sabre': 69.0,
#  'Delve Deeper': 2.3000000000000003,
#  'Delver': 0.8666666666666666,
#  'Dementium II HD': 1.2666666666666666,
#  'Demigod': 13.090909090909092,
#  'Demise of Nations Rome': 1.5,
#  'Democracy 2': 26.200000000000003,
#  'Democracy 3': 5.460714285714286,
#  'Demolition, Inc.': 2.5,
#  'Demon Hunter Chronicles from Beyond': 3.7,
#  'Demonicon': 1.75,
#  'Deponia': 6.588461538461538,
#  'Deponia The Complete Journey': 20.400000000000002,
#  'Depression Quest': 1.55,
#  'Depth': 9.203703703703704,
#  'Depth Hunter 2 Deep Dive': 10.4,
#  'Depths of Peril': 0.2,
#  'Descent': 6.8,
#  'Descent 2': 0.15000000000000002,
#  'Descent Underground': 0.5,
#  'Desktop Dungeons': 29.3,
#  'Despair': 5.425000000000001,
#  'Desperados - Wanted Dead or Alive': 5.6,
#  'Destination Sol': 2.25,
#  'Destiny Warriors': 2.6,
#  'Detective Grimoire': 1.8,
#  'Dethroned!': 0.2333333333333333,
#  'Deus Ex Game of the Year Edition': 5.089189189189189,
#  'Deus Ex Human Revolution': 25.995652173913047,
#  "Deus Ex Human Revolution - Director's Cut": 14.39074074074074,
#  'Deus Ex Human Revolution - The Missing Link': 8.886363636363638,
#  'Deus Ex Invisible War': 1.85,
#  'Deus Ex Revision': 0.25,
#  'Deus Ex The Fall': 2.275,
#  'Dev Guy': 0.75,
#  'Devil May Cry 3 Special Edition': 3.7125,
#  'Devil May Cry 4': 6.372222222222223,
#  'Devil May Cry 4 Special Edition': 7.366666666666667,
#  'Devilian': 7.816666666666666,
#  'Devils Share': 0.7,
#  'Dex': 10.8,
#  'DiRT': 4.0,
#  'DiRT 2': 10.756000000000002,
#  'DiRT 3': 14.120408163265303,
#  'DiRT 3 Complete Edition': 5.1947368421052635,
#  'DiRT Rally': 10.53888888888889,
#  'DiRT Showdown': 5.417391304347826,
#  'Diamond Dan': 0.1,
#  'Diaper Dash': 0.3,
#  'Dig or Die': 7.0,
#  'DiggerOnline': 2.4823529411764707,
#  'Digital Combat Simulator A-10C Warthog': 0.8,
#  'Diner Dash Hometown Hero': 5.1,
#  'DinerTown Tycoon': 1.0,
#  'Dino D-Day': 2.5640625,
#  'Dinosaur Hunt Africa Contract': 0.5,
#  'Dirty Bomb': 7.129743589743589,
#  "Disciples II Gallean's Return": 9.56,
#  'Disciples II Rise of the Elves': 0.3333333333333333,
#  'Disciples III Reincarnation': 179.15,
#  'Disciples III Renaissance': 92.35000000000001,
#  'Disciples III Resurrection': 5.2,
#  'Disciples Sacred Lands Gold': 6.7,
#  'Dishonored': 19.601379310344825,
#  'Dishonored (RU)': 17.84444444444444,
#  'Disney Infinity 2.0': 16.4,
#  'Disney Infinity 3.0 Play Without Limits': 0.6571428571428571,
#  'DisplayFusion': 0.26666666666666666,
#  'Distance': 7.640000000000001,
#  'Distant Star Revenant Fleet': 1.0,
#  'Distant Worlds Universe': 132.0,
#  'District 187': 6.366666666666666,
#  'Dive to the Titanic': 4.7,
#  'Divekick': 5.933333333333334,
#  'Divine Divinity': 3.6333333333333333,
#  'Divine Souls': 2.3000000000000003,
#  'Divinity Dragon Commander': 8.025,
#  'Divinity Dragon Commander Beta': 3.7,
#  'Divinity II - Ego Draconis': 14.95,
#  'Divinity II - The Dragon Knight Saga': 20.55,
#  "Divinity II Developer's Cut": 11.408333333333331,
#  'Divinity Original Sin': 35.52388059701492,
#  'Divinity Original Sin Enhanced Edition': 8.857142857142858,
#  'Dizzel': 2.1033333333333335,
#  'DmC Devil May Cry': 11.93488372093023,
#  'Doc Clock The Toasted Sandwich of Time': 0.9333333333333335,
#  'Doctor Who The Eternity Clock': 2.8,
#  'Dodge': 2.1,
#  'DogFighter': 0.6714285714285715,
#  'Dogfight 1942': 1.8666666666666665,
#  'Dogs of War Online - Beta': 2.0,
#  'Dollar Dash': 1.0,
#  'Dominions 4': 4.6,
#  'Don Bradman Cricket 14': 89.0,
#  "Don't Starve": 22.814649681528664,
#  "Don't Starve Together Beta": 13.545999999999998,
#  'Doodle God': 6.4,
#  'Door Kickers': 4.8769230769230765,
#  'Doorways Prelude': 2.766666666666667,
#  'Doorways The Underworld': 3.6666666666666665,
#  'Dota 2': 202.78549886387108,
#  'Double Action Boogaloo': 4.828888888888889,
#  'Double Dragon Neon': 2.871428571428571,
#  'Down To One': 3.6,
#  'Downwell': 1.7999999999999998,
#  'Dr. Langeskov, The Tiger, and The Terribly Cursed Emerald A Whirlwind Heist': 0.31999999999999995,
#  'Draconian Wars': 1.9,
#  'Dracula Origin': 1.6,
#  "Dracula's Legacy": 2.9,
#  'Dragomon Hunter': 1.581818181818182,
#  'Dragon Age II': 74.56,
#  'Dragon Age Origins': 60.86451612903225,
#  'Dragon Age Origins - Ultimate Edition': 43.26271186440679,
#  'Dragon Age Origins Character Creator': 0.5875,
#  'Dragon Nest': 31.807692307692314,
#  'Dragon Nest Europe': 51.69,
#  'Dragon Quest Heroes': 6.949999999999999,
#  'Dragon The Game': 0.9,
#  "Dragon's Lair": 0.5,
#  "Dragon's Lair 2 Time Warp": 1.3,
#  "Dragon's Prophet": 9.066666666666666,
#  "Dragon's Prophet (EU)": 29.974999999999998,
#  'Dragons and Titans': 3.045833333333333,
#  'Drakensang': 69.45,
#  'Drakensang The River of Time': 1.8,
#  'Draw a Stickman EPIC': 0.8666666666666667,
#  'Drawn The Painted Tower': 3.9,
#  'Dream': 1.55,
#  'Dream Of Mirror Online': 1.2,
#  'Dream Pinball 3D': 0.4,
#  'Dreamfall Chapters': 4.78,
#  'Dreamfall The Longest Journey': 5.449999999999999,
#  'Dreaming Sarah': 0.6,
#  'Driftmoon': 0.3,
#  'Driver San Francisco': 5.85,
#  'Droid Assault': 0.85,
#  'Droplitz': 0.6,
#  'Drunken Robot Pornography': 1.6,
#  'Duck Dynasty': 2.4,
#  'Duck Game': 17.914285714285715,
#  'DuckTales Remastered': 4.4,
#  'Duke Nukem 3D Megaton Edition': 4.2,
#  'Duke Nukem Forever': 10.365,
#  'Duke Nukem Forever ': 4.4,
#  'Dungeon Defenders': 34.380180180180176,
#  'Dungeon Defenders Eternity': 10.633333333333335,
#  'Dungeon Defenders II': 11.023529411764708,
#  'Dungeon Hearts': 1.4000000000000001,
#  'Dungeon Party': 0.3,
#  'Dungeon Siege': 7.909090909090909,
#  'Dungeon Siege 2': 3.7600000000000002,
#  'Dungeon Siege III': 6.34516129032258,
#  'Dungeon Souls': 46.2,
#  'Dungeon of the Endless': 9.811111111111112,
#  'Dungeonbowl Knockout Edition': 0.2,
#  'Dungeonland': 1.7481481481481485,
#  'Dungeons & Dragons Chronicles of Mystara': 3.8999999999999995,
#  'Dungeons & Dragons Daggerdale': 3.2833333333333337,
#  'Dungeons & Dragons Online': 26.0,
#  'Dungeons 2': 14.483333333333334,
#  'Dungeons The Eye of Draconus': 0.9,
#  'Dungeons of Dredmor': 28.450000000000003,
#  'Dust An Elysian Tail': 7.295652173913043,
#  'Dustforce': 4.8066666666666675,
#  'Dustoff Heli Rescue': 3.9,
#  'Dwarfs F2P': 2.8375,
#  'Dwarfs!?': 1.42,
#  'Dying Light': 27.6575,
#  'Dynamite Jack': 0.2,
#  'Dynasty Warriors 8 - Empires': 11.5,
#  'Dynomite! Deluxe': 1.9,
#  'Dysan the Shapeshifter': 1.4,
#  'Dysfunctional Systems Learning to Manage Chaos': 2.5999999999999996,
#  'E.Y.E Divine Cybermancy': 4.683333333333333,
#  'EDGE': 1.1,
#  'ENKI': 0.3,
#  'ENSLAVED Odyssey to the West Premium Edition': 2.9333333333333336,
#  'EVE Online': 34.885714285714286,
#  ...}

# %%
#To get the avg time played for a game
avg_dict['Dota 2']
# Out:
# 202.78549886387108

# %%
#Select only the rows where players played more than average
played_games_sup_avg = played_games_orig.loc[played_games_orig['hours_played'] > played_games_orig['game'].astype(str).map(avg_dict)]
played_games_sup_avg.sort_values(by='id')
# Out:
#                id                                         game  hours_played
# 65423        5250                              Cities Skylines         144.0
# 65425        5250                     Deus Ex Human Revolution          62.0
# 55918       76767                             Total War ATTILA         207.0
# 55920       76767  Call of Duty Modern Warfare 2 - Multiplayer         165.0
# 55922       76767                Call of Duty Modern Warfare 2          65.0
# ...           ...                                          ...           ...
# 150248  307631446            MEDIEVAL Total War - Gold Edition          14.2
# 177078  307688442                                    Hurtworld          65.0
# 96358   307701164                                Emily is Away           0.9
# 117507  309255941                            Mitos.is The Game           5.7
# 169504  309554670                            Mitos.is The Game           5.9
#
# [18331 rows x 3 columns]

# %%
g = played_games_sup_avg.drop('hours_played', axis=1)
g = g.groupby('id')['game'].apply(list).reset_index(name='games')
print(g)
te2 = TransactionEncoder()
te_ary2 = te2.fit(g['games']).transform(g['games'])
df2 = pd.DataFrame(te_ary2, columns=te2.columns_)
fis2 = fpgrowth(df2, min_support=0.0005, use_colnames=True)
fis2 = fis2.sort_values(by=['support'], ascending=False)
fis2
# Out:
#              id                                              games
# 0          5250        [Cities Skylines, Deus Ex Human Revolution]
# 1         76767  [Counter-Strike, Call of Duty World at War, To...
# 2         86540  [The Elder Scrolls V Skyrim, Audiosurf, Killer...
# 3        229911  [Counter-Strike Condition Zero, Call of Duty M...
# 4        298950  [Team Fortress 2, Counter-Strike Global Offens...
# ...         ...                                                ...
# 4237  307631446                [MEDIEVAL Total War - Gold Edition]
# 4238  307688442                                        [Hurtworld]
# 4239  307701164                                    [Emily is Away]
# 4240  309255941                                [Mitos.is The Game]
# 4241  309554670                                [Mitos.is The Game]
#
# [4242 rows x 2 columns]
#         support                                      itemsets
# 140    0.202263                                      (Dota 2)
# 12     0.093352             (Counter-Strike Global Offensive)
# 13     0.081094                             (Team Fortress 2)
# 617    0.059642                                    (Unturned)
# 8      0.049033                  (The Elder Scrolls V Skyrim)
# ...         ...                                           ...
# 8520   0.000707               (BioShock 2, BioShock Infinite)
# 8521   0.000707                   (Saints Row IV, BioShock 2)
# 8522   0.000707            (Saints Row The Third, BioShock 2)
# 8524   0.000707  (Team Fortress 2, Borderlands 2, BioShock 2)
# 19812  0.000707                           (WARMODE, Unturned)
#
# [19813 rows x 2 columns]

# %%
ar2 = association_rules(fis2, metric="confidence", min_threshold=0.2)
ar2 = ar2.sort_values(by=['confidence'], ascending=False)
ar2
# Out:
#                                              antecedents  \
# 39235  (The Elder Scrolls V Skyrim, The Witcher 3 Wil...
# 77382       (Left 4 Dead 2, Starbound, Orcs Must Die! 2)
# 55279  (BioShock Infinite, Dishonored, The Witcher 3 ...
# 55280  (Fallout 4, Dishonored, The Witcher 3 Wild Hun...
# 22746         (Wargame AirLand Battle, Empire Total War)
# ...                                                  ...
# 23908  (Call of Duty Modern Warfare 2 - Multiplayer, ...
# 23927                           (Far Cry 3 Blood Dragon)
# 23939                           (Far Cry 3 Blood Dragon)
# 23969                           (Far Cry 3 Blood Dragon)
# 25158                                             (RIFT)
#
#                                              consequents  antecedent support  \
# 39235  (Divinity Original Sin, Pillars of Eternity, F...            0.000707
# 77382                                         (Terraria)            0.000707
# 55279  (Fallout 4, The Witcher 2 Assassins of Kings E...            0.000707
# 55280  (The Witcher 2 Assassins of Kings Enhanced Edi...            0.000707
# 22746                            (Europa Universalis IV)            0.000707
# ...                                                  ...                 ...
# 23908             (Team Fortress 2, Aliens vs. Predator)            0.003536
# 23927             (Sleeping Dogs, Psychonauts, BioShock)            0.003536
# 23939  (Sleeping Dogs, Psychonauts, Deus Ex Human Rev...            0.003536
# 23969  (Sleeping Dogs, BioShock, Psychonauts, Deus Ex...            0.003536
# 25158        (Left 4 Dead 2, The Elder Scrolls V Skyrim)            0.003536
#
#        consequent support   support  confidence         lift  leverage  \
# 39235            0.000707  0.000707         1.0  1414.000000  0.000707
# 77382            0.031825  0.000707         1.0    31.422222  0.000685
# 55279            0.003300  0.000707         1.0   303.000000  0.000705
# 55280            0.002122  0.000707         1.0   471.333333  0.000706
# 22746            0.003065  0.000707         1.0   326.307692  0.000705
# ...                   ...       ...         ...          ...       ...
# 23908            0.001179  0.000707         0.2   169.680000  0.000703
# 23927            0.000943  0.000707         0.2   212.100000  0.000704
# 23939            0.000707  0.000707         0.2   282.800000  0.000705
# 23969            0.000707  0.000707         0.2   282.800000  0.000705
# 25158            0.004950  0.000707         0.2    40.400000  0.000690
#
#        conviction
# 39235         inf
# 77382         inf
# 55279         inf
# 55280         inf
# 22746         inf
# ...           ...
# 23908    1.248527
# 23927    1.248821
# 23939    1.249116
# 23969    1.249116
# 25158    1.243812
#
# [78470 rows x 9 columns]

# %%
librairy = ['Cities Skylines']
print(librairy)
print(recommendation_ar(librairy, fis2, ar2))

for i in range (10):
    librairy = g.iloc[i][1]
    print(librairy)
    print(recommendation_ar(librairy, fis2, ar2))
    print('\n')
# Out:
# ['Cities Skylines']
# ['Prison Architect']
# ['Cities Skylines', 'Deus Ex Human Revolution']
# ['Half-Life 2', 'Prison Architect', 'The Elder Scrolls V Skyrim', 'Team Fortress 2', 'Dishonored', 'Metro 2033', 'Fallout New Vegas']
#
#
# ['Counter-Strike', 'Call of Duty World at War', 'Total War ATTILA', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Call of Duty Modern Warfare 2', 'Call of Duty Black Ops']
# ['Dota 2', 'Empire Total War', 'DayZ', 'The Elder Scrolls V Skyrim', 'Alien Swarm', 'Portal 2', 'Napoleon Total War', 'Call of Duty Modern Warfare 3', 'Call of Duty Modern Warfare 3 - Multiplayer', 'Rising Storm/Red Orchestra 2 Multiplayer', 'Mount & Blade Warband', 'Aliens vs. Predator', 'Portal', 'Fallout 4', 'Call of Duty Black Ops - Multiplayer', 'Crusader Kings II', 'Company of Heroes 2', 'Total War ROME II - Emperor Edition', 'Total War SHOGUN 2', 'PAYDAY 2', 'Metro 2033', 'Counter-Strike Global Offensive', 'RAGE', 'Team Fortress 2']
#
#
# ['The Elder Scrolls V Skyrim', 'Audiosurf', 'Killer is Dead']
# ['Left 4 Dead 2', 'Killing Floor', 'Portal 2', 'Half-Life 2', 'Monaco', 'Trine', 'Team Fortress 2', 'Terraria']
#
#
# ['Counter-Strike Condition Zero', 'Call of Duty Modern Warfare 2']
# ['Call of Duty Modern Warfare 2 - Multiplayer', 'Counter-Strike', 'Call of Duty Black Ops', 'Call of Duty Modern Warfare 3']
#
#
# ['Team Fortress 2', 'Counter-Strike Global Offensive', 'The Elder Scrolls V Skyrim', 'Far Cry 3', 'Fallout New Vegas', 'The Witcher 3 Wild Hunt', 'Terraria', 'Fallout 4', 'Borderlands 2', 'DARK SOULS II Scholar of the First Sin', 'Endless Legend', 'Divinity Original Sin', 'Pillars of Eternity', 'Starbound', 'Dark Souls Prepare to Die Edition', 'The Witcher 2 Assassins of Kings Enhanced Edition', 'STAR WARS Knights of the Old Republic II The Sith Lords', 'Tropico 4', 'Deus Ex Human Revolution', 'Dishonored', "Shadowrun Dragonfall - Director's Cut", 'Darksiders II', 'BioShock Infinite', 'Legend of Grimrock', 'Dead Island', 'Hitman Absolution', 'Mark of the Ninja', 'Amnesia The Dark Descent', 'Sanctum', 'Brothers - A Tale of Two Sons', 'NiGHTS into Dreams...']
# ['Crysis 2 Maximum Edition', 'Killing Floor', 'Empire Total War', 'Crysis', 'Crusader Kings II', 'Dead Space 2', 'Left 4 Dead 2', 'Mass Effect', "Sid Meier's Civilization V", 'Total War ROME II - Emperor Edition', 'Half-Life 2 Episode One', 'PAYDAY The Heist', 'Orcs Must Die! 2', 'Half-Life 2', 'Fallout 3 - Game of the Year Edition', 'Super Meat Boy', 'Dying Light', 'Papers, Please', 'Shadowrun Returns', 'Overlord', 'Outlast', 'Alan Wake', 'Medal of Honor(TM) Single Player', 'DayZ', 'Dungeon Defenders', 'Age of Wonders III', 'Portal', 'State of Decay', 'Dead Island Riptide', "Tom Clancy's Splinter Cell Blacklist", 'Star Wars Knights of the Old Republic', 'Mass Effect 2', 'Amnesia A Machine for Pigs', 'The Binding of Isaac Rebirth', 'Overlord II', 'Metro 2033', 'Section 8 Prejudice', 'Warlock - Master of the Arcane', 'Saints Row IV', 'Bastion', 'Portal 2', 'Dead Space', 'Sins of a Solar Empire Rebellion', 'Defense Grid The Awakening', 'Batman Arkham Origins', 'FTL Faster Than Light', 'Arma 2', "Assassin's Creed IV Black Flag", 'PAYDAY 2', 'Deus Ex Game of the Year Edition', 'Dear Esther', 'Homeworld Remastered Collection', 'Hotline Miami', 'Deus Ex Human Revolution - The Missing Link', 'Call of Duty Black Ops', 'Saints Row The Third', 'Trine 2', 'Unturned', 'Red Faction Guerrilla Steam Edition', 'Castle Crashers', 'Grand Theft Auto IV', 'Rogue Legacy', 'Arma 2 Operation Arrowhead', 'XCOM Enemy Unknown', 'Total War SHOGUN 2', 'Magicka', "Mirror's Edge", 'The Witcher Enhanced Edition', 'Tropico 5', 'BioShock', 'Alien Swarm', 'BioShock 2', 'Mount & Blade Warband', 'Resident Evil 5 / Biohazard 5', 'Chivalry Medieval Warfare', 'L.A. Noire', 'Metro Last Light', 'Middle-earth Shadow of Mordor', 'F.E.A.R.', 'Far Cry 3 Blood Dragon', 'Mafia II', 'Prison Architect', 'Dota 2', 'The Elder Scrolls IV Oblivion ', "Garry's Mod", 'Wolfenstein The New Order', 'Call of Duty Modern Warfare 3 - Multiplayer', 'Warhammer 40,000 Dawn of War II', 'Half-Life 2 Lost Coast', 'Just Cause 2 Multiplayer Mod', 'Insurgency', 'Warhammer 40,000 Dawn of War II - Chaos Rising', 'The Stanley Parable', 'Kerbal Space Program', 'Valiant Hearts The Great War / Soldats Inconnus  Mmoires de la Grande Guerre', 'Half-Life 2 Episode Two', 'Torchlight', 'BattleBlock Theater', 'Endless Space', 'Star Wars The Force Unleashed Ultimate Sith Edition', 'Deadlight', 'Surgeon Simulator', 'Left 4 Dead', 'LIMBO', 'Tomb Raider', 'Resident Evil 6 / Biohazard 6', 'Borderlands', 'Borderlands The Pre-Sequel', 'Red Faction Armageddon', 'DARK SOULS II', 'War Thunder', 'Counter-Strike Source', 'Sleeping Dogs', 'RAGE', 'Dragon Age Origins', 'Darksiders', 'Psychonauts', "Don't Starve", 'SOMA', 'Half-Life', 'Torchlight II', 'Batman Arkham City', 'The Walking Dead', 'Burnout Paradise The Ultimate Box', 'Warframe', "Assassin's Creed III", 'Just Cause 2', 'The Walking Dead Season Two', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Batman Arkham Asylum GOTY Edition', 'Reus', 'The Wolf Among Us', 'Batman Arkham City GOTY', 'Trine', 'Remember Me']
#
#
# ['Counter-Strike Global Offensive']
# ['Dota 2']
#
#
# ['Counter-Strike Source']
# ['Counter-Strike Global Offensive']
#
#
# ['Call of Duty Modern Warfare 3 - Multiplayer', 'Call of Duty Black Ops II', 'Borderlands', 'Eufloria', 'RAGE', 'Portal 2', 'Metro 2033', 'Half-Life 2', 'Duke Nukem Forever', 'Sniper Elite V2', 'Half-Life 2 Episode Two', 'Serious Sam HD The First Encounter', 'F.E.A.R. 3', 'Operation Flashpoint Red River', 'Portal', 'Osmos', 'Medal of Honor(TM) Single Player', "Alan Wake's American Nightmare", 'Sanctum', 'Killing Floor Mod Defence Alliance 2', 'Ignite']
# ['Killing Floor', 'Crysis 2 Maximum Edition', 'Alien Swarm', 'Crysis', 'BioShock 2', 'BioShock Infinite', 'Fallout 4', 'Chivalry Medieval Warfare', 'Terraria', 'Call of Duty Ghosts', 'Metro Last Light', 'Left 4 Dead 2', 'L.A. Noire', 'Amnesia The Dark Descent', 'Deus Ex Human Revolution', 'Half-Life 2 Episode One', 'PAYDAY The Heist', 'Borderlands 2', 'Fallout 3 - Game of the Year Edition', 'Far Cry 3', 'Mafia II', 'Super Meat Boy', 'Dying Light', 'Dota 2', 'Alan Wake', "Garry's Mod", 'Dungeon Defenders', 'Warhammer 40,000 Dawn of War II', 'Half-Life 2 Lost Coast', 'The Stanley Parable', 'State of Decay', 'Fallout New Vegas', 'Dead Island', 'Half-Life Blue Shift', 'Star Wars - Battlefront II', 'Mass Effect 2', 'And Yet It Moves', 'Dishonored', 'Homefront', 'Call of Duty Black Ops II - Zombies', 'Bastion', 'Dead Space', 'Metro 2033 Redux', 'Darksiders II', 'Tomb Raider', 'FTL Faster Than Light', 'Evolve', 'The Witcher 2 Assassins of Kings Enhanced Edition', 'Call of Duty Modern Warfare 2', 'PAYDAY 2', 'War Thunder', 'Sleeping Dogs', 'Dark Souls Prepare to Die Edition', 'Hotline Miami', 'Team Fortress 2', 'BRINK', 'Deus Ex Human Revolution - The Missing Link', 'Call of Duty Black Ops', 'Saints Row The Third', 'Half-Life', 'Beat Hazard', 'The Elder Scrolls V Skyrim', 'The Witcher 3 Wild Hunt', 'Trine 2', 'Call of Duty Modern Warfare 3', 'F.E.A.R. 2 Project Origin', 'Starbound', 'The Walking Dead', 'Aliens vs. Predator', 'Burnout Paradise The Ultimate Box', 'Warframe', 'Grand Theft Auto IV', 'Castle Crashers', 'Monday Night Combat', 'Rogue Legacy', 'Just Cause 2', 'Magicka', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Medal of Honor(TM) Multiplayer', 'Batman Arkham Asylum GOTY Edition', 'Batman Arkham City GOTY', 'Counter-Strike Global Offensive', "Mirror's Edge", 'Synergy', 'Max Payne 3', 'BioShock', 'Portal Stories Mel']
#
#
# ['Counter-Strike Global Offensive']
# ['Dota 2']
#
#
# ['Team Fortress 2', 'Left 4 Dead 2', 'Left 4 Dead', 'Just Cause 2', 'Batman Arkham City GOTY', "Assassin's Creed III", "Assassin's Creed II", 'Portal 2', 'Magicka', 'Deus Ex Human Revolution', 'Amnesia The Dark Descent', 'RAGE', 'Rogue Legacy', 'Serious Sam 3 BFE', 'Defense Grid The Awakening', 'Batman Arkham Asylum GOTY Edition', 'Crysis 2 Maximum Edition', 'S.T.A.L.K.E.R. Shadow of Chernobyl', 'DeathSpank', 'The Secret of Monkey Island Special Edition', 'Frozen Synapse', 'Metro 2033', 'Hotline Miami', "Brothers in Arms Hell's Highway", 'Renegade Ops', 'Alien Swarm', 'VVVVVV', "Mirror's Edge", 'Blocks That Matter', 'Galcon Fusion', 'The Path', 'The Stanley Parable', 'Zeno Clash', 'Plain Sight', 'Thief Deadly Shadows', 'McPixel', 'Braid', 'Rock of Ages', 'The Typing of The Dead Overkill', 'Half-Life Blue Shift', 'Madballs in...Babo Invasion', 'BIT.TRIP RUNNER', 'DEFCON', 'Jamestown', 'DogFighter', 'Proteus', 'Avadon The Black Fortress', 'A Valley Without Wind 2', 'Scoregasm']
# ['Killing Floor', 'Empire Total War', 'Crysis', 'Fallout 4', 'Terraria', 'Dead Space 2', "Sid Meier's Civilization V", 'Half-Life 2 Episode One', 'Painkiller Hell & Damnation', 'PAYDAY The Heist', 'Borderlands 2', 'Orcs Must Die! 2', 'Half-Life 2', 'Monaco', 'Fallout 3', 'Super Meat Boy', "Assassin's Creed Brotherhood", 'Dying Light', 'Gotham City Impostors', 'S.T.A.L.K.E.R. Call of Pripyat', 'Papers, Please', 'Overlord', 'Kingdoms of Amalur Reckoning', 'Alan Wake', 'Outlast', 'System Shock 2', 'DayZ', 'Killing Floor 2', 'The Swapper', 'Mark of the Ninja', 'Dungeon Defenders', 'Age of Wonders III', 'Portal', 'Company of Heroes', 'State of Decay', 'Worms Reloaded', 'Magic Duels', 'Star Wars Knights of the Old Republic', 'Fallout New Vegas', 'Star Wars - Battlefront II', 'Mass Effect 2', 'Amnesia A Machine for Pigs', 'The Binding of Isaac Rebirth', 'Far Cry 2', 'Dishonored', 'Section 8 Prejudice', 'Saints Row IV', 'Bastion', 'Dead Space', 'Monkey Island 2 Special Edition', 'Rising Storm/Red Orchestra 2 Multiplayer', 'Batman Arkham Origins', 'FTL Faster Than Light', 'Arma 2', "Assassin's Creed IV Black Flag", 'The Witcher 2 Assassins of Kings Enhanced Edition', 'PAYDAY 2', 'Tropico 4', 'Antichamber', 'Dear Esther', 'Dark Souls Prepare to Die Edition', 'Deus Ex Human Revolution - The Missing Link', 'BRINK', 'Call of Duty Black Ops', 'Saints Row The Third', 'Beat Hazard', 'BIT.TRIP BEAT', 'Trine 2', 'F.E.A.R. 2 Project Origin', 'Battlefield Bad Company 2', 'Red Faction Guerrilla Steam Edition', 'Aliens vs. Predator', 'Castle Crashers', 'Grand Theft Auto IV', 'Monday Night Combat', 'Shadow Warrior', 'Grand Theft Auto V', 'F.E.A.R. 3', 'Defense Grid 2', 'Long Live The Queen', 'The Talos Principle', 'Titan Quest', 'Machinarium', 'Counter-Strike Global Offensive', 'Max Payne 3', 'The Witcher Enhanced Edition', 'BioShock', 'STAR WARS Knights of the Old Republic II The Sith Lords', 'Grand Theft Auto Episodes from Liberty City', 'BioShock 2', 'Mount & Blade Warband', 'BioShock Infinite', 'Resident Evil 5 / Biohazard 5', 'Chivalry Medieval Warfare', 'Metro Last Light', 'Middle-earth Shadow of Mordor', 'Hitman Absolution', 'DC Universe Online', "Deus Ex Human Revolution - Director's Cut", 'Far Cry 3', 'Mafia II', 'Prison Architect', "Tom Clancy's Splinter Cell Conviction", 'Dota 2', "Garry's Mod", 'The Binding of Isaac', 'Warhammer 40,000 Dawn of War II', 'S.T.A.L.K.E.R. Clear Sky', 'Crayon Physics Deluxe', 'Just Cause 2 Multiplayer Mod', 'Brothers - A Tale of Two Sons', 'Kerbal Space Program', 'Dead Island', 'Half-Life 2 Episode Two', 'Torchlight', 'Star Wars The Force Unleashed Ultimate Sith Edition', 'Deadlight', 'Serious Sam HD The First Encounter', 'The Elder Scrolls III Morrowind', 'LIMBO', 'Darksiders II', 'Tomb Raider', 'Resident Evil 6 / Biohazard 6', "Assassin's Creed", 'Borderlands', 'Evolve', 'Call of Duty Modern Warfare 2', 'War Thunder', 'Counter-Strike Source', 'Dragon Age Origins', 'Sleeping Dogs', "Don't Starve Together Beta", 'Psychonauts', 'Half-Life Opposing Force', 'Gunpoint', 'Half-Life', 'SOMA', "Don't Starve", 'Torchlight II', "Tom Clancy's Rainbow Six Vegas 2", 'The Elder Scrolls V Skyrim', 'Starbound', 'The Walking Dead', 'Call of Duty Modern Warfare 3', 'Burnout Paradise The Ultimate Box', 'NightSky', 'Warframe', 'Sniper Elite V2', 'Legend of Grimrock', 'Call of Duty Modern Warfare 2 - Multiplayer', 'Trine']

# %% [markdown]
# Let's evaluate our model

# %%
geval = g
print(geval)
geval = geval.sample(frac=1, random_state=42)
train_nb = int(geval.shape[0] / 100 * 85)
print(train_nb)
X_train = geval[:train_nb]
X_test = geval[train_nb:]
print(X_train)
X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 geval = g
#       2 print(geval)
#       3 geval = geval.sample(frac=1, random_state=42)
#
# NameError: name 'g' is not defined

# %%
te3 = TransactionEncoder()
te_ary3 = te3.fit(X_train['games']).transform(X_train['games'])
dftrain = pd.DataFrame(te_ary3, columns=te3.columns_)
fistrain = fpgrowth(dftrain, min_support=0.0005, use_colnames=True)
fistrain = fistrain.sort_values(by=['support'], ascending=False)
fistrain
# Out:
#           support                                           itemsets
# 3        0.206012                                           (Dota 2)
# 4        0.091954                  (Counter-Strike Global Offensive)
# 61       0.078691                                  (Team Fortress 2)
# 140      0.058650                                         (Unturned)
# 8        0.048630                       (The Elder Scrolls V Skyrim)
# ...           ...                                                ...
# 1495593  0.000589  (Intergalactic Bubbles, BEEP, Skyborn, Squishy...
# 1495594  0.000589  (Intergalactic Bubbles, BEEP, Skyborn, Squishy...
# 1495595  0.000589  (Intergalactic Bubbles, Afterfall InSanity Ext...
# 1495596  0.000589  (Intergalactic Bubbles, BEEP, Skyborn, Squishy...
# 4464019  0.000589  (Gothic 3 Forsaken Gods Enhanced Edition, The ...
#
# [4464020 rows x 2 columns]

# %%
artrain = association_rules(fistrain, metric="confidence", min_threshold=0.2)
artrain = artrain.sort_values(by=['antecedent support'], ascending=False)
artrain
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
X_test_formatted = X_test

def remove_n_random_items(lst, n):
    if(len(lst)>1):
        to_delete = set(sample(range(len(lst)), n))

        return [
            item for index, item in enumerate(lst)
            if not index in to_delete
        ]


X_test_formatted['incomplet_games'] = X_test_formatted['games'].apply(lambda x : remove_n_random_items(x,1))
X_test_formatted = X_test_formatted.dropna()
print(X_test_formatted)
# Out:
#              id                                              games  \
# 4069  273437868  [FEZ, Child of Light, Another World, You Have ...
# 1787  111362598  [Dota 2, Counter-Strike Global Offensive, Arma...
# 262    29852387              [Counter-Strike, Assassin's Creed II]
# 1634  104159428  [Arma 2 Operation Arrowhead, Orcs Must Die! 2,...
# 2198  132180557  [Call of Duty World at War, RollerCoaster Tyco...
# ...         ...                                                ...
# 769    60217594  [Counter-Strike, Counter-Strike Global Offensi...
# 1685  106834867  [Team Fortress 2, Portal 2, Half-Life, Half-Li...
# 130    14906179  [Counter-Strike Source, Half-Life 2 Deathmatch...
# 3171  188681523  [Counter-Strike Global Offensive, PAYDAY 2, In...
# 466    44240866  [Call of Duty Modern Warfare 2 - Multiplayer, ...
#
#                                         incomplet_games
# 4069               [FEZ, Child of Light, Another World]
# 1787  [Dota 2, Counter-Strike Global Offensive, Arma...
# 262                               [Assassin's Creed II]
# 1634     [Arma 2 Operation Arrowhead, Orcs Must Die! 2]
# 2198  [Call of Duty World at War, RollerCoaster Tyco...
# ...                                                 ...
# 769   [Counter-Strike, Counter-Strike Global Offensi...
# 1685  [Team Fortress 2, Half-Life, Half-Life Opposin...
# 130   [Counter-Strike Source, Half-Life 2 Deathmatch...
# 3171  [Counter-Strike Global Offensive, PAYDAY 2, In...
# 466   [Call of Duty Modern Warfare 2 - Multiplayer, ...
#
# [114 rows x 3 columns]
# /tmp/ipykernel_4620/2656098971.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_formatted['incomplet_games'] = X_test_formatted['games'].apply(lambda x : remove_n_random_items(x,1))

# %%
true_pos = 0
false_pos = 0

for i in tqdm(range(X_test_formatted.shape[0])):
    item_removed = set(X_test_formatted.iloc[i][1]).difference(set(X_test_formatted.iloc[i][2]))
    recommended_games = recommendation_ar(X_test_formatted.iloc[i][2],fistrain,artrain)
    if(item_removed.issubset(set(recommended_games))):
        true_pos = true_pos + 1
    else :
        false_pos = false_pos +1

precision = true_pos/(true_pos+false_pos)
print(true_pos)
print(false_pos)
print(precision)
# Out:
# 100%|██████████| 114/114 [09:23<00:00,  4.95s/it]
# 36
# 78
# 0.3157894736842105
